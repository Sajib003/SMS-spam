# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
df=pd.read_csv('new_data2.csv', encoding='latin-1')
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5750 entries, 0 to 5749
# Data columns (total 5 columns):
# label          5750 non-null int64
# message        5750 non-null object
# length         5750 non-null int64
# punctuation    5750 non-null float64
# token          5750 non-null object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 224.7+ KB
# None
#    label                                            message  length  \
# 0      0  go jurong point crazi avail bugi n great world...     111
# 1      0                              ok lar joke wif u oni      29
# 2      1  free entri numbr wkli comp win fa cup final tk...     155
# 3      0                u dun say earli hor u c alreadi say      49
# 4      0          nah dont think goe usf live around though      61
#
#    punctuation                                              token
# 0     8.108108  ['go', 'jurong', 'point', 'crazi', 'avail', 'b...
# ...

# %%
svc = SVC()
knc = KNeighborsClassifier(n_neighbors=50)
rfc = RandomForestClassifier(n_estimators=30)
abc = AdaBoostClassifier(n_estimators=50)
gbc = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=1, random_state=0)

models = {'SVC' : svc,'KN' : knc,'RF': rfc,'ABC':abc,'GBC':gbc}

# %%
df_x = df[['length', 'punctuation']]
df_y=df['label']

# %%
sv=[]
kn=[]
rf=[]
ab=[]
gb=[]
arr=[]
sv2=[]
kn2=[]
rf2=[]
ab2=[]
gb2=[]
arr2=[]

sv.append(cross_val_score(svc,df_x,df_y,cv=10,scoring='accuracy'))
kn.append(cross_val_score(knc,df_x,df_y,cv=10,scoring='accuracy'))
rf.append(cross_val_score(rfc,df_x,df_y,cv=10,scoring='accuracy'))
ab.append(cross_val_score(abc,df_x,df_y,cv=10,scoring='accuracy'))
gb.append(cross_val_score(gbc,df_x,df_y,cv=10,scoring='accuracy'))

sv2.append(cross_val_score(svc,df_x,df_y,cv=10,scoring='f1_weighted'))
kn2.append(cross_val_score(knc,df_x,df_y,cv=10,scoring='f1_weighted'))
rf2.append(cross_val_score(rfc,df_x,df_y,cv=10,scoring='f1_weighted'))
ab2.append(cross_val_score(abc,df_x,df_y,cv=10,scoring='f1_weighted'))
gb2.append(cross_val_score(gbc,df_x,df_y,cv=10,scoring='f1_weighted'))

a=np.average(sv)
b=np.average(kn)
c=np.average(rf)
d=np.average(ab)
e=np.average(gb)
arr=[a,b,c,d,e]

a2=np.average(sv2)
b2=np.average(kn2)
c2=np.average(rf2)
d2=np.average(ab2)
e2=np.average(gb2)
arr2=[a2,b2,c2,d2,e2]
# Out:
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
tb = pd.DataFrame(columns=['Accuracy(Metadata)','F1(Metadata)'],index=['SVM', 'KNN', 'RF' , 'AB' , 'GB'])
tb['Accuracy(Metadata)']=arr
tb['F1(Metadata)']=arr2
print(tb)
# Out:
#      Accuracy(Metadata)  F1(Metadata)
# SVM            0.880347      0.876199
# KNN            0.884003      0.881398
# RF             0.877391      0.872628
# AB             0.882608      0.885781
# GB             0.882955      0.882759

# %%
cv = CountVectorizer()
df_x = cv.fit_transform(df['message']).toarray()
df_y=df['label']

# %%
sv=[]
kn=[]
rf=[]
ab=[]
gb=[]
arr=[]
sv2=[]
kn2=[]
rf2=[]
ab2=[]
gb2=[]
arr2=[]

sv.append(cross_val_score(svc,df_x,df_y,cv=10,scoring='accuracy'))
kn.append(cross_val_score(knc,df_x,df_y,cv=10,scoring='accuracy'))
rf.append(cross_val_score(rfc,df_x,df_y,cv=10,scoring='accuracy'))
ab.append(cross_val_score(abc,df_x,df_y,cv=10,scoring='accuracy'))
gb.append(cross_val_score(gbc,df_x,df_y,cv=10,scoring='accuracy'))

sv2.append(cross_val_score(svc,df_x,df_y,cv=10,scoring='f1_weighted'))
kn2.append(cross_val_score(knc,df_x,df_y,cv=10,scoring='f1_weighted'))
rf2.append(cross_val_score(rfc,df_x,df_y,cv=10,scoring='f1_weighted'))
ab2.append(cross_val_score(abc,df_x,df_y,cv=10,scoring='f1_weighted'))
gb2.append(cross_val_score(gbc,df_x,df_y,cv=10,scoring='f1_weighted'))

a=np.average(sv)
b=np.average(kn)
c=np.average(rf)
d=np.average(ab)
e=np.average(gb)
arr=[a,b,c,d,e]

a2=np.average(sv2)
b2=np.average(kn2)
c2=np.average(rf2)
d2=np.average(ab2)
e2=np.average(gb2)
arr2=[a2,b2,c2,d2,e2]
# Out:
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
tb = pd.DataFrame(columns=['Accuracy(CV)','F1(CV)'],index=['SVM', 'KNN', 'RF' , 'AB' , 'GB'])
tb['Accuracy(CV)']=arr
tb['F1(CV)']=arr2
print(tb)
# Out:
#      Accuracy(CV)    F1(CV)
# SVM      0.871823  0.829477
# KNN      0.895295  0.869850
# RF       0.969548  0.963871
# AB       0.959111  0.957004
# GB       0.954591  0.952563

# %%
vectorizer = TfidfVectorizer("english")

# %%
df_x = vectorizer.fit_transform(df['message']).toarray()
df_y=df['label']

# %%
sv=[]
kn=[]
rf=[]
ab=[]
gb=[]
arr=[]
sv2=[]
kn2=[]
rf2=[]
ab2=[]
gb2=[]
arr2=[]

sv.append(cross_val_score(svc,df_x,df_y,cv=10,scoring='accuracy'))
kn.append(cross_val_score(knc,df_x,df_y,cv=10,scoring='accuracy'))
rf.append(cross_val_score(rfc,df_x,df_y,cv=10,scoring='accuracy'))
ab.append(cross_val_score(abc,df_x,df_y,cv=10,scoring='accuracy'))
gb.append(cross_val_score(gbc,df_x,df_y,cv=10,scoring='accuracy'))

sv2.append(cross_val_score(svc,df_x,df_y,cv=10,scoring='f1_weighted'))
kn2.append(cross_val_score(knc,df_x,df_y,cv=10,scoring='f1_weighted'))
rf2.append(cross_val_score(rfc,df_x,df_y,cv=10,scoring='f1_weighted'))
ab2.append(cross_val_score(abc,df_x,df_y,cv=10,scoring='f1_weighted'))
gb2.append(cross_val_score(gbc,df_x,df_y,cv=10,scoring='f1_weighted'))

a=np.average(sv)
b=np.average(kn)
c=np.average(rf)
d=np.average(ab)
e=np.average(gb)
arr=[a,b,c,d,e]

a2=np.average(sv2)
b2=np.average(kn2)
c2=np.average(rf2)
d2=np.average(ab2)
e2=np.average(gb2)
arr2=[a2,b2,c2,d2,e2]
# Out:
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
tb = pd.DataFrame(columns=['Accuracy(TFIDF)','F1(TFIDF)'],index=['SVM', 'KNN', 'RF' , 'AB' , 'GB'])
tb['Accuracy(TFIDF)']=arr
tb['F1(TFIDF)']=arr2
print(tb)
# Out:
#      Accuracy(TFIDF)  F1(TFIDF)
# SVM         0.851653   0.783422
# KNN         0.957545   0.955348
# RF          0.966070   0.964320
# AB          0.959291   0.958137
# GB          0.954243   0.951264

# %%
from gensim.models import Word2Vec

model = Word2Vec(df['token'], min_count=1, size=1000)
# vocab = model.wv.vocab.keys()
# wordsInVocab = len(vocab) 
# print(wordsInVocab)
 
def sent_vectorizer(sent, model):
    sent_vec = np.zeros(1000)
    numw = 0
    for w in sent:
        try:
            sent_vec = np.add(sent_vec, model[w])
            numw+=1
        except:
            pass    
    return sent_vec 
V=[]
for sentence in df['token']:
    V.append(sent_vectorizer(sentence, model))
print(len(V))
pd.DataFrame(V).to_csv("new_data3.csv", header=True,index=False)
# Out:
# C:\Users\Sajib\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   del sys.path[0]
# 5750

# %%
df2=pd.read_csv('new_data3.csv', encoding='latin-1')
top_n = 100
a=[]
for i in df2.index[:]:
    a.append(df2.loc[i].nlargest(top_n))
pd.DataFrame(a).to_csv("new_data4.csv", header=True,index=False)
df_x=list(map(sum, a))

# %%
df['vect'] = df_x
df
# Out:
#       label                                            message  length  \
# 0         0  go jurong point crazi avail bugi n great world...     111
# 1         0                              ok lar joke wif u oni      29
# 2         1  free entri numbr wkli comp win fa cup final tk...     155
# 3         0                u dun say earli hor u c alreadi say      49
# 4         0          nah dont think goe usf live around though      61
# ...     ...                                                ...     ...
# 5745      1  spot admiss foren scienc cardiac careperfu ren...     156
# 5746      1  cbse privat exam numbr form start class numbrt...     157
# 5747      1  receiv offer lotteri win cheap fund rbigovern ...     134
# 5748      1  gokul sent blue packet expir numbr min get hik...     116
# 5749      1  cbse privat exam numbr form start class numbrt...     157
#
#       punctuation                                              token  \
# ...

# %%
arr=[]
arr = df['vect']
df_x= arr.values.reshape(-1, 1)
df_y=df['label']

# #Spliting the dataset into Training set and Test Set
# train_x, test_x, train_y, test_y = train_test_split(df_x, df_y, test_size= 0.2, random_state=0)
# # print(np.shape(train_x))
# # print(np.shape(test_x))
# train_x= train_x.reshape(-1, 1)
# train_y= train_y.reshape(-1, 1)
# test_x = test_x.reshape(-1, 1)
# # print(np.shape(train_x))
# # print(np.shape(test_x))
sv=[]
kn=[]
rf=[]
ab=[]
gb=[]
arr=[]
sv2=[]
kn2=[]
rf2=[]
ab2=[]
gb2=[]
arr2=[]

sv.append(cross_val_score(svc,df_x,df_y,cv=10,scoring='accuracy'))
kn.append(cross_val_score(knc,df_x,df_y,cv=10,scoring='accuracy'))
rf.append(cross_val_score(rfc,df_x,df_y,cv=10,scoring='accuracy'))
ab.append(cross_val_score(abc,df_x,df_y,cv=10,scoring='accuracy'))
gb.append(cross_val_score(gbc,df_x,df_y,cv=10,scoring='accuracy'))

sv2.append(cross_val_score(svc,df_x,df_y,cv=10,scoring='f1_weighted'))
kn2.append(cross_val_score(knc,df_x,df_y,cv=10,scoring='f1_weighted'))
rf2.append(cross_val_score(rfc,df_x,df_y,cv=10,scoring='f1_weighted'))
ab2.append(cross_val_score(abc,df_x,df_y,cv=10,scoring='f1_weighted'))
gb2.append(cross_val_score(gbc,df_x,df_y,cv=10,scoring='f1_weighted'))

a=np.average(sv)
b=np.average(kn)
c=np.average(rf)
d=np.average(ab)
e=np.average(gb)
arr=[a,b,c,d,e]

a2=np.average(sv2)
b2=np.average(kn2)
c2=np.average(rf2)
d2=np.average(ab2)
e2=np.average(gb2)
arr2=[a2,b2,c2,d2,e2]
# Out:
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Sajib\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
tb = pd.DataFrame(columns=['Accuracy(Word2Vec)','F1(Word2Vec)'],index=['SVM', 'KNN', 'RF' , 'AB' , 'GB'])
tb['Accuracy(Word2Vec)']=arr
tb['F1(Word2Vec)']=arr2
print(tb)
# Out:
#      Accuracy(Word2Vec)  F1(Word2Vec)
# SVM            0.879645      0.864355
# KNN            0.899121      0.896466
# RF             0.889728      0.890026
# AB             0.897554      0.892967
# GB             0.901036      0.897471

# %%
# from sklearn.decomposition import LatentDirichletAllocation
 
# NUM_TOPICS = 10
 
# cv = CountVectorizer(min_df=5, max_df=0.9, stop_words='english', lowercase=True, token_pattern='[a-zA-Z\-][a-zA-Z\-]{2,}')
# data_vectorized = cv.fit_transform(df['message'])
 
# # Build a Latent Dirichlet Allocation Model
# lda_model = LatentDirichletAllocation(n_topics=NUM_TOPICS, max_iter=10, learning_method='online')
# lda_Z = lda_model.fit_transform(data_vectorized)
 
# text = "The economy is working better than ever"
# x = lda_model.transform(vectorizer.transform([text]))[0]
# print(x, x.sum())
